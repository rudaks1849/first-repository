# %% [markdown]
# <a href="https://colab.research.google.com/github/rudaks1849/first-repository/blob/main/251222_%EC%8B%A4%EC%8A%B5_%EC%9D%B4%EA%B0%80%ED%98%84_%EA%B8%88%EA%B2%BD%EB%A7%8C(revised).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 숫자야구 만들기 실습! (이가현, 금경만)

# %% [markdown]
# # 로직 정리
# 1. 정답 설정 (랜덤)
# 2. 입력 5자리 받기
# 3. strike / ball 판단

# %%
import random
numbers = list(range(0, 10))
answer = random.sample(numbers, 5)

print("숫자야구를 시작해보자!")

while True:
  print("0부터 9까지 서로 다른 숫자 5개를 입력하세요!")
  player_numbers = list(map(int, input().strip()))

  strike = 0
  ball = 0

  for i in range(5):
    if player_numbers[i] == answer[i]:
      strike += 1

    elif player_numbers[i] in answer:
      ball += 1

  print(f"당신의 정답은 {strike} strike, {ball} ball")

  if strike == 5:
    break

print("축하합니다!! 정답입니다!!")
print(answer)
# Out:
# 숫자야구를 시작해보자!
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 12345
# 당신의 정답은 0 strike, 3 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 12346
# 당신의 정답은 0 strike, 2 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 12357
# 당신의 정답은 0 strike, 3 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 12358
# 당신의 정답은 0 strike, 3 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 12359
# 당신의 정답은 0 strike, 4 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 02359
# 당신의 정답은 0 strike, 5 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 20359
# 당신의 정답은 0 strike, 5 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 20395
# 당신의 정답은 0 strike, 5 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 02359
# 당신의 정답은 0 strike, 5 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 35092
# 당신의 정답은 0 strike, 5 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 50392
# 당신의 정답은 1 strike, 4 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 50329
# 당신의 정답은 2 strike, 3 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 53029
# 당신의 정답은 3 strike, 2 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 50329
# 당신의 정답은 2 strike, 3 ball
# 0부터 9까지 서로 다른 숫자 5개를 입력하세요!
# 53092
# 당신의 정답은 2 strike, 3 ball
# ...
